# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
churn_data=pd.read_csv('customer.csv')

# %%
churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn_data.shape
# Out:
# (7043, 21)

# %%
churn_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
churn_data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_data[churn_data['TotalCharges']==' ']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
churn_data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_data['TotalCharges']=pd.to_numeric(churn_data['TotalCharges'], errors='coerce')

# %%
churn_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
churn_data.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
churn_data['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
#churn_data['TotalCharges'].fillna(churn_data['TotalCharges'].mean())
#churn_data['gender'].fillna(churn_data['gender'].mode()[0])

# %%
churn_data=churn_data.dropna()

# %%
#churn_data.dropna(inplace=True)

# %%
churn_data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_data.shape
# Out:
# (7032, 21)

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
churn_data.drop(columns = ['customerID'],inplace = True)

# %%
churn_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
churn_data.shape
# Out:
# (7032, 20)

# %%
churn_data.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
churn_data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
churn_data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#extract all the columns which is having object format data
col_list=[]
for col in churn_data.columns:
    if(churn_data[col].dtype=='object'):
        col_list.append(col)
col_list
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
col_list.pop(-1)
# Out:
# 'Churn'

# %%
col_list
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
'''churn_data['gender'] = churn_data['gender'].map({'Male': 1, 'Female': 0})
churn_data['Partner'] = churn_data['Partner'].map({'Yes': 1, 'No': 0})
churn_data['Dependents'] = churn_data['Dependents'].map({'Yes': 1, 'No': 0})
churn_data['PhoneService']= churn_data['PhoneService'].map({'Yes': 1,'No': 0})
churn_data['MultipleLines']=churn_data['MultipleLines'].map({'No phone service':0, 'No': 1, "Yes": 2})
churn_data['InternetService']=churn_data['InternetService'].map({'DSL':0, 'Fiber optic':1, 'No':2})
churn_data['OnlineSecurity']=churn_data['OnlineSecurity'].map({'Yes':1, 'No':0, 'No internet service':2})
churn_data['OnlineBackup']=churn_data['OnlineBackup'].map({'Yes':1, 'No':0, 'No internet service':2})
churn_data['DeviceProtection']=churn_data['DeviceProtection'].map({'Yes':1, 'No':0, 'No internet service':2})
churn_data['TechSupport']=churn_data['TechSupport'].map({'Yes':1, 'No':0, 'No internet service':2})
churn_data['StreamingTV']=churn_data['StreamingTV'].map({'Yes':1, 'No':0, 'No internet service':2})
churn_data['StreamingMovies']=churn_data['StreamingMovies'].map({'Yes':1, 'No':0, 'No internet service':2})
churn_data['Contract']=churn_data['Contract'].map({'Month-to-month':0, 'One year':1, 'Two year':2})
churn_data['PaperlessBilling']=churn_data['PaperlessBilling'].map({'Yes':1, 'No':0})
churn_data['PaymentMethod']=churn_data['PaymentMethod'].map({'Electronic check':1, 'Mailed check':0, 'Bank transfer (automatic)':2, 'Credit card (automatic)':3})'''
'''

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
for i in col_list:
    churn_data[i]=label_encoder.fit_transform(churn_data[i])

# %%
churn_data.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
churn_data.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService       int64
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract              int64
# PaperlessBilling      int64
# PaymentMethod         int64
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
#churn_data['Churn'] = churn_data['Churn'].map({'Yes': 1, 'No': 0})

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(1, 2, figsize= (16, 6))
sns.scatterplot(x="TotalCharges", y = "tenure" , hue="Churn", data=churn_data, ax=ax[0])
sns.scatterplot(x="MonthlyCharges", y = "tenure" , hue="Churn", data=churn_data, ax=ax[1])

# %%
churn_data.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001819 -0.001379    0.010349  0.005285
# SeniorCitizen    -0.001819       1.000000  0.016957   -0.210550  0.015683
# Partner          -0.001379       0.016957  1.000000    0.452269  0.381912
# Dependents        0.010349      -0.210550  0.452269    1.000000  0.163386
# tenure            0.005285       0.015683  0.381912    0.163386  1.000000
# PhoneService     -0.007515       0.008392  0.018397   -0.001078  0.007877
# MultipleLines    -0.006908       0.146287  0.142717   -0.024975  0.343673
# InternetService  -0.002236      -0.032160  0.000513    0.044030 -0.029835
# OnlineSecurity   -0.014899      -0.127937  0.150610    0.151198  0.327283
# OnlineBackup     -0.011920      -0.013355  0.153045    0.090231  0.372434
# DeviceProtection  0.001348      -0.021124  0.165614    0.079723  0.372669
# TechSupport      -0.006695      -0.151007  0.126488    0.132530  0.324729
# ...

# %%
# Step-1: Select the training set.

# Step-2: Build the decision trees associated with the selected data.

# Step-3: Choose the number N for decision trees that you want to build.

# Step-4: For the data points, find the predictions of each decision tree, 
#and assign the new data points to the category that wins the majority votes.

# %%
churn_data.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
X =churn_data.iloc[:, :-1] #independent data
y = churn_data.iloc[:, -1]#target data

# %%
X
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7032, dtype: object

# %%
X.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train1.shape
# Out:
# (5625, 19)

# %%
X_test1.shape
# Out:
# (1407, 19)

# %%
classifier1 = RandomForestClassifier(n_estimators=500)
classifier1.fit(X_train1, y_train1)
y_pred1 = classifier1.predict(X_test1)

# %%
y_pred1
# Out:
# array(['No', 'No', 'No', ..., 'Yes', 'No', 'No'], dtype=object)

# %%
y_pred1.shape
# Out:
# (1407,)

# %%
y_test1
# Out:
# 5561     No
# 5814     No
# 2645     No
# 3983    Yes
# 6438    Yes
#        ...
# 2757     No
# 5702    Yes
# 1662    Yes
# 2766     No
# 2918     No
# Name: Churn, Length: 1407, dtype: object

# %%
y_test1.shape
# Out:
# (1407,)

# %%
c1=confusion_matrix(y_test1, y_pred1)
print(c1)
# Out:
# [[930 108]
#  [188 181]]

# %%
a1=accuracy_score(y_test1, y_pred1)
print(a1)
# Out:
# 0.7896233120113717

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#accuracy wrt number of trees where criterion is gini

num_of_trees=[100,200,300,400,500,600,700,800,900,1000]
accuracy_list=[]
for i in num_of_trees:
    model = RandomForestClassifier(n_estimators=i)
    model.fit(X_train1, y_train1)
    pred = model.predict(X_test1)
    a=accuracy_score(y_test1, pred)
    accuracy_list.append(a)

# %%
d={'Number of trees':num_of_trees, 'Accuracy': accuracy_list }
df=pd.DataFrame(d)
df
df.sort_values(by='Accuracy', ascending=False)
# Out:
#    Number of trees  Accuracy
# 9             1000  0.793177
# 5              600  0.791756
# 7              800  0.791756
# 3              400  0.791045
# 4              500  0.791045
# 2              300  0.790334
# 8              900  0.788913
# 0              100  0.788202
# 6              700  0.787491
# 1              200  0.786780

# %%
#accuracy wrt number of trees where criterion is entropy

num_of_trees=[100,200,300,400,500,600,700,800,900,1000]
accuracy_list=[]
for i in num_of_trees:
    model = RandomForestClassifier(n_estimators=i, criterion='entropy')
    model.fit(X_train1, y_train1)
    pred = model.predict(X_test1)
    a=accuracy_score(y_test1, pred)
    accuracy_list.append(a)

# %%
d1={'Number of trees':num_of_trees, 'Accuracy': accuracy_list }
df1=pd.DataFrame(d1)
df1
# Out:
#    Number of trees  Accuracy
# 0              100  0.793177
# 1              200  0.789623
# 2              300  0.791045
# 3              400  0.786070
# 4              500  0.788202
# 5              600  0.788202
# 6              700  0.790334
# 7              800  0.792466
# 8              900  0.790334
# 9             1000  0.791756

# %%
df1.sort_values(by='Accuracy', ascending=False)
# Out:
#    Number of trees  Accuracy
# 0              100  0.793177
# 7              800  0.792466
# 9             1000  0.791756
# 2              300  0.791045
# 6              700  0.790334
# 8              900  0.790334
# 1              200  0.789623
# 4              500  0.788202
# 5              600  0.788202
# 3              400  0.786070

# %%
#Sensitivity: the ability of a test to correctly identify the churned out customers. 
#sen=TP/TP+FN
#Specificity: the ability of a test to correctly identify people who have not churned out.
#sep: =TN/TN+FP

# %%
#sensitivity
sen1=c1[0,0]/(c1[0,0]+c1[1,0])
sen1
# Out:
# 0.8318425760286225

# %%
#specificity
sep1=c1[1,1]/(c1[1,1]+c1[0,1])

# %%
sep1
# Out:
# 0.6262975778546713

# %%
a1=accuracy_score(y_test1, y_pred1)
print(a1)
# Out:
# 0.7896233120113717

# %%
#from sklearn.datasets import make_classification
importance = classifier1.feature_importances_

# %%
importance
# Out:
# array([0.02743289, 0.02180219, 0.02229704, 0.01969182, 0.15956953,
#        0.00527117, 0.02370989, 0.02778994, 0.03922767, 0.02791625,
#        0.02368947, 0.04479248, 0.01728685, 0.01798094, 0.07451594,
#        0.02653006, 0.05151853, 0.17780822, 0.19116911])

# %%
X
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
importance= pd.Series(importance)
importance
# Out:
# 0     0.027433
# 1     0.021802
# 2     0.022297
# 3     0.019692
# 4     0.159570
# 5     0.005271
# 6     0.023710
# 7     0.027790
# 8     0.039228
# 9     0.027916
# 10    0.023689
# 11    0.044792
# 12    0.017287
# 13    0.017981
# 14    0.074516
# 15    0.026530
# 16    0.051519
# 17    0.177808
# 18    0.191169
# dtype: float64

# %%
df=pd.DataFrame(columns=['Feature','Importance'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Feature, Importance]
# Index: []

# %%
list(X.columns)
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges']

# %%
df['Feature']=list(X.columns)

# %%
df
# Out:
#              Feature Importance
# 0             gender        NaN
# 1      SeniorCitizen        NaN
# 2            Partner        NaN
# 3         Dependents        NaN
# 4             tenure        NaN
# 5       PhoneService        NaN
# 6      MultipleLines        NaN
# 7    InternetService        NaN
# 8     OnlineSecurity        NaN
# 9       OnlineBackup        NaN
# 10  DeviceProtection        NaN
# 11       TechSupport        NaN
# 12       StreamingTV        NaN
# 13   StreamingMovies        NaN
# 14          Contract        NaN
# 15  PaperlessBilling        NaN
# 16     PaymentMethod        NaN
# 17    MonthlyCharges        NaN
# 18      TotalCharges        NaN

# %%
#df['Feature']=col_list

# %%
importance
# Out:
# 0     0.027433
# 1     0.021802
# 2     0.022297
# 3     0.019692
# 4     0.159570
# 5     0.005271
# 6     0.023710
# 7     0.027790
# 8     0.039228
# 9     0.027916
# 10    0.023689
# 11    0.044792
# 12    0.017287
# 13    0.017981
# 14    0.074516
# 15    0.026530
# 16    0.051519
# 17    0.177808
# 18    0.191169
# dtype: float64

# %%
df['Importance']=importance

# %%
df
# Out:
#              Feature  Importance
# 0             gender    0.027433
# 1      SeniorCitizen    0.021802
# 2            Partner    0.022297
# 3         Dependents    0.019692
# 4             tenure    0.159570
# 5       PhoneService    0.005271
# 6      MultipleLines    0.023710
# 7    InternetService    0.027790
# 8     OnlineSecurity    0.039228
# 9       OnlineBackup    0.027916
# 10  DeviceProtection    0.023689
# 11       TechSupport    0.044792
# 12       StreamingTV    0.017287
# 13   StreamingMovies    0.017981
# 14          Contract    0.074516
# 15  PaperlessBilling    0.026530
# 16     PaymentMethod    0.051519
# 17    MonthlyCharges    0.177808
# 18      TotalCharges    0.191169

# %%
df.sort_values(by='Importance', ascending=False)
# Out:
#              Feature  Importance
# 18      TotalCharges    0.191169
# 17    MonthlyCharges    0.177808
# 4             tenure    0.159570
# 14          Contract    0.074516
# 16     PaymentMethod    0.051519
# 11       TechSupport    0.044792
# 8     OnlineSecurity    0.039228
# 9       OnlineBackup    0.027916
# 7    InternetService    0.027790
# 0             gender    0.027433
# 15  PaperlessBilling    0.026530
# 6      MultipleLines    0.023710
# 10  DeviceProtection    0.023689
# 2            Partner    0.022297
# 1      SeniorCitizen    0.021802
# 3         Dependents    0.019692
# 13   StreamingMovies    0.017981
# 12       StreamingTV    0.017287
# 5       PhoneService    0.005271

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(25,6))
# make barplot and sort bars
sns.barplot(x='Feature',y="Importance",data=df, order=df.sort_values('Importance', ascending=False).Feature)
