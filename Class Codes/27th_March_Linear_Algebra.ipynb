# %%
# Matrix, Array

# %%
# Colgate | P&G 

# Save Transaction - 
# Excel, CSV, JSON, Databases[Oracel, SQL Server, MS Server], ERP [SAP, Microsft Dynamics AX],  CRM [SalesForces]

# %%
# tabluar data 
# Array - 1D 
# Matrix - 2D 

# Python - Array 
# 1D - [2, 5, 4, 3]
# 2D - [[1,2,3], 
#.      [3,2,1], 
#.      [3,0,0]]

# 3D - [[[1,2,3], 
        #   [3,2,1], 
        #   [0,0,0]], 
        
        # [[1,1,1],
        #  [2,1,2],
        #  [3,2,1]]]

# %%
# Matrix Operations 
import numpy as np

# %%
m1 = np.random.randint(0, 9, (3,2))
m2 = np.random.randint(0, 9, (2,4))

# %%
m1
# Out:
# array([[4, 7],
#        [1, 3],
#        [1, 8]])

# %%
m2
# Out:
# array([[3, 7, 8, 8],
#        [4, 8, 2, 6]])

# %%
np.dot(m1, m2)
# Out:
# array([[40, 84, 46, 74],
#        [15, 31, 14, 26],
#        [35, 71, 24, 56]])

# %%
m1
# Out:
# array([[4, 7],
#        [1, 3],
#        [1, 8]])

# %%
m1.T
# Out:
# array([[4, 1, 1],
#        [7, 3, 8]])

# %%
m2.T
# Out:
# array([[3, 4],
#        [7, 8],
#        [8, 2],
#        [8, 6]])

# %%
m1 + 4
# Out:
# array([[ 8, 11],
#        [ 5,  7],
#        [ 5, 12]])

# %%
np.eye(3, dtype=int) # 3*3
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
# Inverse of A = Adj(A) / Det(A)

# %%
m2
# Out:
# array([[3, 7, 8, 8],
#        [4, 8, 2, 6]])

# %% [markdown]
# ![Screenshot 2022-03-27 at 10.06.10 PM.png](data:image/png;base64,...)

# %%
m3 = np.random.randint(0, 10, (3,3))

# %%
np.linalg.inv(m3)
# Out:
# array([[ 0.        ,  0.23076923, -0.07692308],
#        [ 0.        , -0.19230769,  0.23076923],
#        [ 0.33333333,  0.23076923, -0.41025641]])

# %%
np.linalg.det(m3)
# Out:
# 78.0

# %%
m5 = np.array([
               [3,2,1], 
               [4,0,2], 
               [2,2,4]
               ])

# %%
m5
# Out:
# array([[3, 2, 1],
#        [4, 0, 2],
#        [2, 2, 4]])

# %%
m6 = np.random.randint(0, 9, (4,4))

# %%
np.linalg.det(m6)
# Out:
# 252.00000000000003

# %%
# matrix , det

# %%
m6
# Out:
# array([[0, 1, 2, 0],
#        [2, 0, 8, 4],
#        [7, 6, 1, 7],
#        [3, 4, 2, 6]])

# %%
m6.sum(axis=1)
# Out:
# array([ 3, 14, 21, 15])

# %%
m6.sum(axis=0)
# Out:
# array([12, 11, 13, 17])
